# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAkram392/Bias_Variance/blob/main/Bias_%26_Variance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Note : In machine learning, the ideal algorithm has low bias and can accurately the true model and it has low variability by producing consistent predictions accross different datasets.
# (This is  done by finding a sweet spot between a simple and complex model)
#
# Three commonly used methods for finding a sweet spot are as follow:
#
#
#
# 1.   Regularization
# 2.   Boosting
# 3.   Bagging

# %% [markdown]
# # Bias
#
# Thr inability of machine learning method (like linear regression) to capture the true relationship is called bias.

# %% [markdown]
# # High Bias

# %% [markdown]
# ![bias.PNG](data:image/png;base64,...)

# %% [markdown]
# # Low Bias

# %% [markdown]
# ![squiggly.PNG](data:image/png;base64,...)

# %% [markdown]
# The squiggly line is super flexible and hugs the training set along the arc of the true relationship, and as it captures the true relation it has little bias.

# %% [markdown]
# # Variance
#
# In machine learning lingo, the different in fits between the datasets is called varaince
